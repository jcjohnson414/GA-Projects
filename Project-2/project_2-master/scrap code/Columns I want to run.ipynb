# %% [markdown]
# MS SubClass --- int64
# MS Zoning --- object
# Lot Shape --- int64
# Lot Config --- int64
# Neighborhood --- int64
# Condition 1 --- object
# House Style --- object
# Overall Qual --- int64
# Overall Cond --- int64
# Exterior 1st --- object
# Exterior 2nd --- object
# Exter Qual --- object
# Foundation --- object
# Bsmt Qual --- object
# BsmtFin Type 1 --- object
# Heating QC --- object
# Full Bath --- int64
# Bedroom AbvGr --- int64
# Kitchen Quality --- object
# TotRms AbvGrd ---int64
# Fireplaces --- int64
# Fireplace Quality --- object
# Garage Type --- object
# Garage Finish --- object
#
#
# 'MS SubClass (Norminal)',
# 'MS Zoning (Nominal)',
# 'Lot Shape (Ordinal)',
# 'Lot Config (Nominal)',
# 'Neighborhood (Nominal)',
# 'Condition 1 (Nominal)',
# 'House Style (Nominal)',
# 'Overall Qual (Ordinal)',
# 'Overall Cond (Ordinal)',
# 'Exterior 1st (Nominal)',
# 'Exterior 2nd (Nominal)',
# 'Exter Qual (Ordinal)',
# 'Foundation (Nominal)',
# 'Bsmt Qual (Ordinal)',
# 'BsmtFin Type 1 (Ordinal)',
# 'Heating QC (Ordinal)',
# 'Full Bath (Discrete)',
# 'Bedroom AbvGr (Discrete)',
# 'Kitchen Quality (Ordinal)',
# 'TotRms AbvGrd (Discrete)',
# 'Fireplaces (Discrete)',
# 'Fireplace Quality (Ordinal)',
# 'Garage Type (Nominal)',
# 'Garage Finish (Ordinal)']
#
#
# nan values
# Alley, non numeric NOMINAL
# Mas Vnr Type, non numeric NOMINAL
# Bsmt Qual, non numeric ORDINAL
# Bsmt Cond, non numeric ORDINAL
# Bsmt Exposure, non numeric ORDINAL
# BsmtFin Type 1, non numeric ORDINAL
# BsmtFin Type 2, non numeric ORDINAL
# Bsmt Full Bath, numeric DISCRETE
# Bsmt Half Bath, numeric DISCRETE
# Fireplace Qu, numeric DISCRETE
# Garage Type, non numeric NOMINAL
# Garage Finish, non numeric ORDINAL
# Garage Cars, numeric DISCRETE
# Garage Qual, non numeric ORDINAL
# Garage Cond, non numeric ORDINAL
# Pool QC, non numeric ORDINAL
# Fence, non numeric ORDINAL
# Misc Feature, non numeric NOMINAL
